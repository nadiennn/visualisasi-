# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #93acf0;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Visualisasi Data Dataset
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data Penumpang Titanic
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
data = pd.read_csv(url)

# Contoh visualisasi
data['Age'].plot(kind='bar')
plt.title("Visualisasi Data")
plt.show()

# %%
import pandas as pd

df1 = pd.read_csv("TIME,Promo(X1),Karyawan(X2),Penjualan_Kopi(Y)")
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 df1 = pd.read_csv("TIME,Promo(X1),Karyawan(X2),Penjualan_Kopi(Y)")
#       4 df1
#
# ...
