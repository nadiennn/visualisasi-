# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Muat data dari URL
url_penjualan = 'https://raw.githubusercontent.com/Alam-A99/Pandas_Latih/10ebb3af000e930a44989075733f495d5c2f4be5/penjualan.csv'
df_penjualan = pd.read_csv(url_penjualan)

# Melt the DataFrame to have months as a single column
df_melted = df_penjualan.melt(id_vars=['nama'], value_vars=['jan', 'feb', 'mar', 'apr'], var_name='Month', value_name='Sales')

# Define the order of months
month_order = ['jan', 'feb', 'mar', 'apr']
df_melted['Month'] = pd.Categorical(df_melted['Month'], categories=month_order, ordered=True)

# Sort by nama and then by month
df_melted = df_melted.sort_values(['nama', 'Month'])

# Create line plot
plt.figure(figsize=(10, 6))
for name in df_melted['nama'].unique():
    df_subset = df_melted[df_melted['nama'] == name]
    plt.plot(df_subset['Month'], df_subset['Sales'], marker='o', label=name)

plt.title('Penjualan dari Waktu ke Waktu (Januari - April)')
plt.xlabel('Bulan')
plt.ylabel('Total Penjualan')
plt.grid(True)
plt.legend(title='Nama')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Membuat plot garis
plt.plot(x, y)

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Membuat plot garis
plt.plot(x, y)

# Menambahkan judul dan label
plt.title("Contoh Plot Garis")
plt.xlabel("Sumbu X")
plt.ylabel("Sumbu Y")

# Menampilkan plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# %%
import matplotlib.pyplot as plt 
# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
# Membuat plot garis
plt.plot(x, y)
# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #eeddd3;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#  BAR PLOT
# </div>

# %%
import matplotlib.pyplot as plt
# Data
x = ["G", "H", "I", "J", "K"]
Y = [8, 3, 5, 10, 19]
# Membuat bar plot
plt.bar(x, y)
# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #eeddd3;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Histogram
# </div>

# %%
import matplotlib.pyplot as plt
# Data
data = [5, 7, 9, 4, 1, 11, 15, 2, 6, 3]
# Membuat histogram
plt.hist(data)
# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #eeddd3;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
# Pie Chart
# </div>

# %%
import matplotlib.pyplot as plt
# Data
labels =["A", "B", "C", "D"]
sizes = [24, 12, 34, 11]
# Membuat pie chart
plt.pie(sizes, labels=labels)
#Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #eeddd3;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
# Boxplot
# </div>

# %%
# !pip install seaborn
# Memanggil library yang diperlukan
import matplotlib.pyplot as plt
import seaborn as sns
penguins = sns.load_dataset("penguins")
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #eeddd3;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
# Boxplot tuunggal
# </div>

# %%
sns.boxplot(x=penguins['bill_length_mm'])
# Out:
# <Axes: xlabel='bill_length_mm'>

# %%
sns.boxplot(y=penguins['bill_length_mm'])
# Out:
# <Axes: ylabel='bill_length_mm'>

# %%
sns.boxenplot(x=penguins["species"],
y=penguins['bill_length_mm'])
# atau
sns.boxplot(data=penguins,x="species",
y='bill_length_mm')
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
sns.boxplot(data=penguins,x="species",
y='bill_length_mm', color="lime")
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
sns.boxplot(data=penguins, x="species", 
y='bill_length_mm', palette="bright")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19296\1112910782.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x="species",
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
custom_pal = {"Adelie": "#9A0EEA", "Chinstrap": "beige", "Gentoo":"c"}

sns.boxplot(data=penguins, x="species", y='bill_length_mm', palette=custom_pal)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19296\915792534.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x="species", y='bill_length_mm', palette=custom_pal)
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
custom_pal = {"Adelie": "#9A0EEA", "Chinstrap": "beige", "Gentoo":"c"}

sns.boxplot(data=penguins,

            x="species", y='bill_length_mm',

            palette=custom_pal,

            linewidth=0.7,

            width=0.4)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19296\2300012014.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins,
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
custom_pal = {"Adelie": "#9A0EEA",
"Chinstrap": "beige", "Gentoo":"c"}

sns.boxplot(data=penguins,

            x="species", y='bill_length_mm',

            palette=custom_pal,

            linewidth=0.7,

            width=0.4,

            notch=True,

            fliersize=10,

            flierprops={"marker": "o"})
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_19296\445669857.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins,
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=penguins,

            x="species", y='bill_length_mm', hue="sex",

            palette="bright",

            linewidth=0.8,

            width=0.5,

            fliersize=3,

            flierprops={"marker": "o"})
# Out:
# <Axes: xlabel='species', ylabel='bill_length_mm'>

# %%
# Mengatur ukuran frame

plt.figure(figsize=(8, 6))

sns.boxplot(data=penguins,

            x="species", y='bill_length_mm', hue="sex",

            palette="bright",

            linewidth=0.8,

            width=0.5,

            fliersize=3,

            flierprops={"marker": "o"})

plt.legend(bbox_to_anchor=(1, 0.6), loc=2, borderaxespad=1)

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6), sharex=False)

sns.boxplot(data=penguins, x="species", y='bill_length_mm', width=0.6, ax=axes[0, 0])

sns.boxplot(data=penguins, x="species", y='bill_depth_mm', width=0.6, ax=axes[0, 1])

sns.boxplot(data=penguins, x="species", y='flipper_length_mm', width=0.6, ax=axes[1, 0])

sns.boxplot(data=penguins, x="species", y='body_mass_g', width=0.6, ax=axes[1, 1])

 

fig.tight_layout()

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6), sharex=False)

p1 = sns.boxplot(data=penguins, x="species", y='bill_length_mm', width=0.6, ax=axes[0, 0])

p2 = sns.boxplot(data=penguins, x="species", y='bill_depth_mm', width=0.6, ax=axes[0, 1])

p3 = sns.boxplot(data=penguins, x="species", y='flipper_length_mm', width=0.6, ax=axes[1, 0])

p4 = sns.boxplot(data=penguins, x="species", y='body_mass_g', width=0.6, ax=axes[1, 1])

plot = [p1, p2, p3, p4]

label = ["Bill Length (mm)", "Bill Depth (mm)", "Flipper Length (mm)", "Body Mass (g)"]

# untuk setiap diagram, hapus label pada sumbu x dan y

# dan set judul diagram yang sesuai

for i in range(0, 4):

    plot[i].set(ylabel=None, xlabel=None)

    plot[i].axes.set_title(label[i], fontsize=11)

   

fig.tight_layout()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #eeddd3;
#             color: #2C3E50;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
# Line Chart Data Time Series
# </div>

# %%
import pandas as pd
coffe_nelo = pd.read_csv("Coffe_nelo.csv")
print(coffe_nelo)
# Out:
#     hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 0            10      card   38.7                Latte     Morning     Fri
# 1            12      card   38.7        Hot Chocolate   Afternoon     Fri
# 2            12      card   38.7        Hot Chocolate   Afternoon     Fri
# 3            13      card   28.9            Americano   Afternoon     Fri
# 4            13      card   38.7                Latte   Afternoon     Fri
# 5            15      card   33.8  Americano with Milk   Afternoon     Fri
# 6            16      card   38.7        Hot Chocolate   Afternoon     Fri
# 7            18      card   33.8  Americano with Milk       Night     Fri
# 8            19      card   38.7                Cocoa       Night     Fri
# 9            19      card   33.8  Americano with Milk       Night     Fri
# 10           19      card   33.8  Americano with Milk       Night     Fri
# 11           10      card   28.9            Americano     Morning     Sat
# ...

# %%
coffe_nelo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  24 non-null     int64
#  1   cash_type    24 non-null     object
#  2   money        24 non-null     float64
#  3   coffee_name  24 non-null     object
#  4   Time_of_Day  24 non-null     object
#  5   Weekday      24 non-null     object
#  6   Month_name   24 non-null     object
#  7   Weekdaysort  24 non-null     int64
#  8   Monthsort    24 non-null     int64
#  9   Date         24 non-null     object
#  10  Time         24 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.2+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(110, 97))
sns.lineplot(data=coffe_nelo, x='Date',
 y='coffee_name')
plt.show()

# %%
import pandas as pd
import seaborn as sns
coffe_nelo = pd.read_csv("coffe_nelo.csv")
print(coffe_nelo)
# Out:
#     hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 0            10      card   38.7                Latte     Morning     Fri
# 1            12      card   38.7        Hot Chocolate   Afternoon     Fri
# 2            12      card   38.7        Hot Chocolate   Afternoon     Fri
# 3            13      card   28.9            Americano   Afternoon     Fri
# 4            13      card   38.7                Latte   Afternoon     Fri
# 5            15      card   33.8  Americano with Milk   Afternoon     Fri
# 6            16      card   38.7        Hot Chocolate   Afternoon     Fri
# 7            18      card   33.8  Americano with Milk       Night     Fri
# 8            19      card   38.7                Cocoa       Night     Fri
# 9            19      card   33.8  Americano with Milk       Night     Fri
# 10           19      card   33.8  Americano with Milk       Night     Fri
# 11           10      card   28.9            Americano     Morning     Sat
# ...

# %%
coffe_nelo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  24 non-null     int64
#  1   cash_type    24 non-null     object
#  2   money        24 non-null     float64
#  3   coffee_name  24 non-null     object
#  4   Time_of_Day  24 non-null     object
#  5   Weekday      24 non-null     object
#  6   Month_name   24 non-null     object
#  7   Weekdaysort  24 non-null     int64
#  8   Monthsort    24 non-null     int64
#  9   Date         24 non-null     object
#  10  Time         24 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 2.2+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 20))
sns.lineplot(data=coffe_nelo, x='Weekdaysort', y='hour_of_day')
plt.show()

# %%
plt.figure(figsize=(15, 20))
sns.lineplot(data=coffe_nelo, x='Weekdaysort', y='hour_of_day', color="green")
plt.show()
